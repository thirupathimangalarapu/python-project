# %%
import numpy as np

# %%
import matplotlib.pyplot as plt #visualization

# %%
from PIL import Image

# %%
feature_image = Image.open(r'C:\Users\user\Desktop\peacock.jpg')

# %%
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=148x148>

# %%
print(type(feature_image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
plt.imshow(feature_image)

# %%
imagea=np.asarray(feature_image)

# %%
imagea
# Out:
# array([[[ 59,  81,  43],
#         [ 28,  50,  12],
#         [ 61,  81,  46],
#         ...,
#         [ 18,  44,  17],
#         [ 30,  56,  29],
#         [ 49,  75,  48]],
#
#        [[ 80, 102,  66],
#         [ 72,  94,  58],
#         [ 47,  68,  35],
#         ...,
#         [ 22,  48,  21],
#         [ 46,  72,  45],
#         [ 60,  86,  59]],
#
#        [[ 39,  60,  27],
#         [ 29,  50,  17],
#         [ 54,  75,  44],
#         ...,
#         [ 27,  56,  28],
#         [ 47,  76,  48],
#         [ 61,  90,  62]],
#
#        ...,
#
#        [[220, 209, 191],
#         [225, 213, 197],
#         [221, 209, 193],
#         ...,
#         [212, 207, 188],
#         [208, 203, 184],
#         [190, 185, 166]],
#
#        [[203, 192, 174],
#         [211, 199, 183],
#         [211, 199, 183],
#         ...,
#         [213, 208, 189],
#         [211, 206, 187],
#         [180, 175, 156]],
#
#        [[178, 167, 149],
#         [188, 176, 160],
#         [190, 178, 162],
# ...

# %%
imagea.shape
# Out:
# (148, 148, 3)

# %%
plt.show()
