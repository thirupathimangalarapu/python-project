# %%
import pandas as pd

# %%
r=pd.read_excel(r'C:\Users\user\Downloads\Rawdata.xlsx')

# %%
id(r)
# Out:
# 2309537943232

# %%
r.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 r.shape()
#
# TypeError: 'tuple' object is not callable

# %%
r.head()
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year

# %%
r.tail()
# Out:
#      Name          Domain     Age   Location   Salary      Exp
# 1  Teddy^         Testing  45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#     NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics     NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics   67-yr        NaN   30000-  5+ year
# 5     Kim             NLP    55yr      Delhi  6000^$0      10+

# %%
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
r.colums()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6628\526226670.py in ?()
# ----> 1 r.colums()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
r.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
r.isnull()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
r.isna()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
r.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
# Data cleaning
r['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
r['Name']=r['Name'].str.replace(r'\W','',regex=True)
r['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
r['Domain']
# Out:
# 0     Datascience#$
# 1           Testing
# 2    Dataanalyst^^#
# 3       Ana^^lytics
# 4        Statistics
# 5               NLP
# Name: Domain, dtype: object

# %%
r['Domain']=r['Domain'].str.replace(r'\W','',regex=True)
r['Domain']
# Out:
# 0    Datascience
# 1        Testing
# 2    Dataanalyst
# 3      Analytics
# 4     Statistics
# 5            NLP
# Name: Domain, dtype: object

# %%
r['Location']=r['Location'].str.replace(r'\W','',regex=True)
r['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2          NaN
# 3     Hyderbad
# 4          NaN
# 5        Delhi
# Name: Location, dtype: object

# %%
r['Age']=r['Age'].str.extract('(\\d+)')
r['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
r['Exp']=r['Exp'].str.extract('(\\d+)')
r['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    NaN
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
r['Salary']=r['Salary'].str.replace(r'\W','',regex=True)
r['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: object

# %%
r
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10
