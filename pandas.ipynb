# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
st=pd.read_excel(r'C:\Users\user\Downloads\data.xlsx')
st
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
st.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
st.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
st.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
st.shape
# Out:
# (195, 5)

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
type(st)
# Out:
# pandas.core.frame.DataFrame

# %%
st.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
st.tail(2)
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Zambia         ZMB     40.471           15.4  Lower middle income
# 194    Zimbabwe         ZWE     35.715           18.5           Low income

# %%
st.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
st.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
st.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
st['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
st['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
st[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
st_nu=st[['BirthRate','InternetUsers']]

# %%
st_nu
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
st_nu.head()
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9
# 1     35.253            5.9
# 2     45.985           19.1
# 3     12.877           57.2
# 4     11.044           88.0

# %%
st.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
st_t=st[['CountryName','CountryCode','IncomeGroup']]
st_t
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
st_t.head()
# Out:
#             CountryName CountryCode          IncomeGroup
# 0                 Aruba         ABW          High income
# 1           Afghanistan         AFG           Low income
# 2                Angola         AGO  Upper middle income
# 3               Albania         ALB  Upper middle income
# 4  United Arab Emirates         ARE          High income

# %%
st[:6]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
st[3:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# 7     Antigua and Barbuda         ATG     16.447           63.4
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# ..                   ...
# ...

# %%
st[3:10]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
st[3:50:5]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 3              Albania         ALB     12.877        57.2000
# 8            Australia         AUS     13.200        83.0000
# 13               Benin         BEN     36.440         4.9000
# 18        Bahamas, The         BHS     15.339        72.0000
# 23             Bolivia         BOL     24.236        36.9400
# 28            Botswana         BWA     25.267        15.0000
# 33               China         CHN     12.100        45.8000
# 38             Comoros         COM     34.326         6.5000
# 43              Cyprus         CYP     11.436        65.4548
# 48  Dominican Republic         DOM     21.198        45.9000
#
#             IncomeGroup
# 3   Upper middle income
# 8           High income
# 13           Low income
# 18          High income
# 23  Lower middle income
# 28  Upper middle income
# 33  Upper middle income
# 38           Low income
# 43          High income
# 48  Upper middle income

# %%
st[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
st[::-2]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 190           Yemen, Rep.         YEM     32.947           20.0
# 188    West Bank and Gaza         PSE     30.394           46.6
# 186               Vietnam         VNM     15.537           43.9
# ..                    ...         ...        ...            ...
# 8               Australia         AUS     13.200           83.0
# 6                 Armenia         ARM     13.308           41.9
# 4    United Arab Emirates         ARE     11.044           88.0
# 2                  Angola         AGO     45.985           19.1
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 192           Low income
# 190  Lower middle income
# 188  Lower middle income
# 186  Lower middle income
# ..                   ...
# ...

# %%
st_nu.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
st.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
st['MyCal']=st.BirthRate * st.InternetUsers

# %%
st.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup     MyCal
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
st1=st.drop('MyCal',axis=1)

# %%
st1
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
st=st1

# %%
st
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                   Aruba         ABW     10.244           78.9  High income
# 1             Afghanistan         AFG     35.253            5.9  High income
# 2                  Angola         AGO     45.985           19.1  High income
# 3                 Albania         ALB     12.877           57.2  High income
# 4    United Arab Emirates         ARE     11.044           88.0  High income
# ..                    ...         ...        ...            ...          ...
# 190           Yemen, Rep.         YEM     32.947           20.0  High income
# 191          South Africa         ZAF     20.850           46.5  High income
# 192      Congo, Dem. Rep.         COD     42.394            2.2  High income
# 193                Zambia         ZMB     40.471           15.4  High income
# 194              Zimbabwe         ZWE     35.715           18.5  High income
#
# [195 rows x 5 columns]

# %%
len(st[st['InternetUsers']>4])
# Out:
# 179

# %%
len(st[st['BirthRate']>40])
# Out:
# 12

# %%
st2=st[st.IncomeGroup=='High income']
st2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                   Aruba         ABW     10.244           78.9  High income
# 1             Afghanistan         AFG     35.253            5.9  High income
# 2                  Angola         AGO     45.985           19.1  High income
# 3                 Albania         ALB     12.877           57.2  High income
# 4    United Arab Emirates         ARE     11.044           88.0  High income
# ..                    ...         ...        ...            ...          ...
# 190           Yemen, Rep.         YEM     32.947           20.0  High income
# 191          South Africa         ZAF     20.850           46.5  High income
# 192      Congo, Dem. Rep.         COD     42.394            2.2  High income
# 193                Zambia         ZMB     40.471           15.4  High income
# 194              Zimbabwe         ZWE     35.715           18.5  High income
#
# [195 rows x 5 columns]

# %%
st2.IncomeGroup.unique()
# Out:
# array(['High income'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as s
# %matplotlib inline
plt.rcParams['figure.figsize']=6,2
import warnings
warnings.filterwarnings('ignore')

# %%
s.distplot(st['InternetUsers'])
plt.show()

# %%
s.displot(st['InternetUsers'])
plt.show()

# %%
s.distplot(st['InternetUsers'],bins=15)
plt.show()

# %%
s.boxenplot(data=st,x='BirthRate',y='InternetUsers')
plt.show()

# %%
s.lmplot(data=st,x='BirthRate',y='InternetUsers',fit_reg=True,hue='IncomeGroup')
plt.show()
